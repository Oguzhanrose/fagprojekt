# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn; seaborn.set_style("darkgrid")
from tqdm.notebook import tqdm
import scipy.stats as st
import random
from itertools import combinations
import statsmodels.stats.multitest as bon 
import os

seed = 1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %% [markdown]
# # Load and preprocess data:

# %%
names = ['epoch', 'id', 'CTC_loss', 'WER', 'ref_WER_lens', 'hyp_WER_lens', 'CER', 'ref_CER_lens', 'hyp_CER_lens']
df_tc2 = pd.read_csv('tacotron2-cutvsdev-cleanY2021-m05-d07-H13-M43.csv', sep='\t', header=None, names=names)
df_base = pd.read_csv('test-clean-cutvsdev-cleanY2021-m05-d07-H13-M43.csv', sep='\t', header=None, names=names)
df_wavenet = pd.read_csv('wavenet-cutvsdev-cleanY2021-m05-d07-H13-M43.csv', sep='\t', header=None, names=names)
df_tc2_wavenet = pd.read_csv('wavenet-tacotron2vsdev-cleanY2021-m06-d08-H14-M05.csv', sep='\t', header=None, names=names)

def set_error_rates(df):
    df['max_WER_lens'] = df['ref_WER_lens']
    df['WER_rate'] = df['WER']/df['max_WER_lens']
    df['max_CER_lens'] = df['ref_CER_lens'] 
    df['CER_rate'] = df['CER']/df['max_CER_lens']
    
set_error_rates(df_tc2)
set_error_rates(df_base)
set_error_rates(df_wavenet)
set_error_rates(df_tc2_wavenet)

# Find the optimal epoch for each model from CTC loss 
df_tc2_epoch = df_tc2.groupby('epoch').mean()['CTC_loss']
df_wavenet_epoch = df_wavenet.groupby('epoch').mean()['CTC_loss']
df_base_epoch = df_base.groupby('epoch').mean()['CTC_loss']
df_tc2_wavenet_epoch = df_tc2_wavenet.groupby('epoch').mean()['CTC_loss']

tc2_epoch = df_tc2_epoch.argmin()
wavenet_epoch = df_wavenet_epoch.argmin()
base_epoch = df_base_epoch.argmin()
tc2_wavenet_epoch = df_tc2_wavenet_epoch.argmin()

print("Optimal Tacotron 2 epoch: {}".format(tc2_epoch))
print("Optimal BERT WaveNet epoch: {}".format(wavenet_epoch))
print("Optimal Mel-spectogram WaveNet epoch: {}".format(base_epoch))
print("Optimal Base epoch: {}".format(tc2_wavenet_epoch))
# Out:
# Optimal Tacotron 2 epoch: 13
# Optimal BERT WaveNet epoch: 52
# Optimal Mel-spectogram WaveNet epoch: 21
# Optimal Base epoch: 71

# %%
# Example of data matrix:
df_wavenet
# Out:
#         epoch                id    CTC_loss  WER  ref_WER_lens  hyp_WER_lens  \
# 0           1  3853-163249-0012  715.077942   50            50             0
# 1           1  3853-163249-0042  572.026306   46            46             0
# 2           1  3853-163249-0052  548.793213   36            36             0
# 3           1  3853-163249-0017  558.689758   41            41             0
# 4           1  3853-163249-0014  509.629944   36            36             0
# ...       ...               ...         ...  ...           ...           ...
# 426082    158   1988-24833-0021  224.988815   14            15            12
# 426083    158   1988-24833-0001  369.975464   27            27            23
# 426084    158   1988-24833-0009  281.900696   19            20            18
# 426085    158   1988-24833-0017  295.664917   22            24            16
# 426086    158   1988-24833-0024  365.935059   21            23            14
#
#         CER  ref_CER_lens  hyp_CER_lens  max_WER_lens  WER_rate  max_CER_lens  \
# 0       255           255             0            50  1.000000           255
# 1       200           200             0            46  1.000000           200
# 2       195           195             0            36  1.000000           195
# 3       199           199             0            41  1.000000           199
# 4       180           180             0            36  1.000000           180
# ...     ...           ...           ...           ...       ...           ...
# 426082   52            77            43            15  0.933333            77
# 426083   96           135            66            27  1.000000           135
# 426084   71            97            61            20  0.950000            97
# 426085   68            99            51            24  0.916667            99
# 426086   80           110            47            23  0.913043           110
#
#         CER_rate
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       1.000000
# 4       1.000000
# ...          ...
# 426082  0.675325
# 426083  0.711111
# 426084  0.731959
# 426085  0.686869
# 426086  0.727273
#
# [426087 rows x 13 columns]

# %%
class _ColorHEX:
    def __init__(self):
        self.blue = "#1f77b4"
        self.orange = "#ff7f0e"
        self.green = "#2ca02c"
        self.red = "#d62728"
        self.purple = "#9467bd" 
        self.brown = "#8c564b"
        self.pink = "#e377c2"
        self.grey =  "#7f7f7f"
colors_hex = _ColorHEX()

# %%
#Best epoch WER and CER
dfs = [df_tc2, df_base, df_wavenet, df_tc2_wavenet]
epochs = [tc2_epoch, wavenet_epoch, base_epoch, tc2_wavenet_epoch]
order = ['tc2', 'base', 'wavenet', 'tc2_wavenet']

# %%
for d, o, e in zip(dfs, df_order, epochs):
    WER_low, CER_low = d[d['epoch'] == e][['WER_rate', 'CER_rate']].quantile(0.05)
    WER_upp, CER_upp = d[d['epoch'] == e][['WER_rate', 'CER_rate']].quantile(0.95)
    WER_mean, CER_mean = d[d['epoch'] == e][['WER_rate', 'CER_rate']].mean(axis=0)
    print()
    print(f"{o} & {WER_low:.3f} & {WER_mean:.3f} & {WER_upp:.3f} & {CER_low:.3f} & {CER_mean:.3f} & {CER_upp:.3f}\\\\")
    print()
# Out:
# tc2 & 0.919 & 1.000 & 1.111 & 0.590 & 0.682 & 0.783\\
#
#
# base & 0.800 & 0.974 & 1.217 & 0.386 & 0.519 & 0.659\\
#
#
# wavenet & 0.952 & 1.050 & 1.308 & 0.696 & 0.744 & 0.800\\
#
#
# tc2_wavenet & 0.941 & 1.130 & 1.562 & 0.673 & 0.724 & 0.781\\

# %% [markdown]
# # Permuation test:

# %%
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)

# Get data for optimal epoch
pd_wavenet = df_wavenet.loc[df_wavenet['epoch'] == wavenet_epoch]
pd_tc2 = df_tc2.loc[df_tc2['epoch'] == tc2_epoch]
pd_base = df_base.loc[df_base['epoch'] == base_epoch]
pd_mel = df_base.loc[df_base['epoch'] == tc2_wavenet_epoch]

# Observe WER and CER (rates) 
pd_wavenet = pd_wavenet[['WER_rate','CER_rate']]
pd_tc2 = pd_tc2[['WER_rate','CER_rate']]
pd_base = pd_base[['WER_rate','CER_rate']]
pd_mel = pd_mel[['WER_rate','CER_rate']]

# Collect CER and Wer for the 4 models 
list1 = [pd_wavenet['WER_rate'], pd_tc2['WER_rate'], pd_base['WER_rate'], pd_mel['WER_rate']]
df_WER = pd.concat(list1,axis=1)

list2 = [pd_wavenet['CER_rate'], pd_tc2['CER_rate'], pd_base['CER_rate'], pd_mel['CER_rate']]
df_CER = pd.concat(list2,axis=1)

def permutation_test(data1, data2):
    permutations = 10000
    
    # Calulate observed permutation statistic
    t_obs = data1.mean()-data2.mean()
    
    # Save t_0 distribution of permutation statistic samples 
    t_vals = np.zeros(permutations)
    
    # 1000 random permutations (with frozen transcript group)
    for k in tqdm(range(permutations)):
        perm = np.random.choice(a=[False, True], size=len(data1))
        
        group1 = perm*data1+np.logical_not(perm)*data2
        group2 = np.logical_not(perm)*data1+perm*data2
        
        s = group1.mean()-group2.mean()
        t_vals[k] = s
    
    # Calculate p-value
    logic_vector = np.logical_or(t_vals >= abs(t_obs), t_vals <= -abs(t_obs))
    pval = np.mean(logic_vector)
        
    return t_obs, t_vals, pval
        
# Permutation tests on WER
t_obs1, t_vals1, p1 = permutation_test(df_WER.iloc[:,0],df_WER.iloc[:,1])
t_obs2, t_vals2, p2 = permutation_test(df_WER.iloc[:,0],df_WER.iloc[:,2])
t_obs3, t_vals3, p3 = permutation_test(df_WER.iloc[:,0],df_WER.iloc[:,3])
t_obs4, t_vals4, p4 = permutation_test(df_WER.iloc[:,1],df_WER.iloc[:,2])
t_obs5, t_vals5, p5 = permutation_test(df_WER.iloc[:,1],df_WER.iloc[:,3])
t_obs6, t_vals6, p6 = permutation_test(df_WER.iloc[:,2],df_WER.iloc[:,3])

# Permutation tests on CER
t_obs7, t_vals7, p7 = permutation_test(df_CER.iloc[:,0],df_WER.iloc[:,1])
t_obs8, t_vals8, p8 = permutation_test(df_CER.iloc[:,0],df_WER.iloc[:,2])
t_obs9, t_vals9, p9 = permutation_test(df_CER.iloc[:,0],df_WER.iloc[:,3])
t_obs10, t_vals10, p10 = permutation_test(df_CER.iloc[:,1],df_WER.iloc[:,2])
t_obs11, t_vals11, p11 = permutation_test(df_CER.iloc[:,1],df_WER.iloc[:,3])
t_obs12, t_vals12, p12 = permutation_test(df_CER.iloc[:,2],df_WER.iloc[:,3])

# Bonferroni correct p-values 
pvals1 = bon.multipletests([p1,p2,p3,p4,p5,p6],alpha=0.05,method="bonferroni")[1]
pvals2 = bon.multipletests([p7,p8,p9,p10,p11,p12],alpha=0.05,method="bonferroni")[1]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))

# %%
for i in range(6):
    print("p-value {}: {}".format(i,pvals1[i]))
for i in range(6):
    print("p-value {}: {}".format(i,pvals2[i]))
# Out:
# p-value 0: 0.0
# p-value 1: 0.0
# p-value 2: 0.0
# p-value 3: 0.0
# p-value 4: 0.0
# p-value 5: 0.0
# p-value 0: 0.0
# p-value 1: 0.0
# p-value 2: 0.0
# p-value 3: 0.0
# p-value 4: 0.0
# p-value 5: 0.0

# %%
names = ["wavenet", "tc2", "base", "mel"]
#cer
order = [[0,1],[0,2],[0,3],[1,2],[1,3],[2,3]]

p_labels = [f"{names[i]} & vs. & {names[j]}" for i,j in order]

# %%
t_obss1 = [t_obs1, t_obs2, t_obs3, t_obs4, t_obs5, t_obs6]
t_obss2 = [t_obs7, t_obs8, t_obs9, t_obs10, t_obs11, t_obs12]

# %%
def pretty_print_float(f):
    flt = "{0:.3e}".format(f)
    b, e = flt.split("e")
    e = "{"+str(int(e))+"}"
    return f"${b} \cdot 10^{e}$"

# %%
for i,l in enumerate(p_labels):
    print(f"{l}\t & {pretty_print_float(pvals1[i])}\t & {pretty_print_float(t_obss1[i])}\t  & {pretty_print_float(pvals2[i])}\t & {pretty_print_float(t_obss2[i])}\\\\")
# Out:
# wavenet & vs. & tc2	 & $0.000 \cdot 10^{0}$	 & $1.028 \cdot 10^{-1}$	  & $0.000 \cdot 10^{0}$	 & $-2.703 \cdot 10^{-1}$\\
# wavenet & vs. & base	 & $0.000 \cdot 10^{0}$	 & $7.887 \cdot 10^{-2}$	  & $0.000 \cdot 10^{0}$	 & $-2.943 \cdot 10^{-1}$\\
# wavenet & vs. & mel	 & $0.000 \cdot 10^{0}$	 & $1.258 \cdot 10^{-1}$	  & $0.000 \cdot 10^{0}$	 & $-2.473 \cdot 10^{-1}$\\
# tc2 & vs. & base	 & $0.000 \cdot 10^{0}$	 & $-2.395 \cdot 10^{-2}$	  & $0.000 \cdot 10^{0}$	 & $-3.416 \cdot 10^{-1}$\\
# tc2 & vs. & mel	 & $0.000 \cdot 10^{0}$	 & $2.300 \cdot 10^{-2}$	  & $0.000 \cdot 10^{0}$	 & $-2.947 \cdot 10^{-1}$\\
# base & vs. & mel	 & $0.000 \cdot 10^{0}$	 & $4.695 \cdot 10^{-2}$	  & $0.000 \cdot 10^{0}$	 & $-4.344 \cdot 10^{-1}$\\

# %% [markdown]
# # Two-sample non-parameteric bootstrapping:

# %%
# Set random seed 
random.seed(1)
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)

# Significance level
numb_comparisons = 6
sign_level = 0.05/numb_comparisons 

# Calculate statistics 
mapping = {"Tacotron2": df_tc2.loc[ df_tc2.epoch == tc2_epoch, "WER_rate"],
           "Baseline": df_base.loc[ df_base.epoch == base_epoch, "WER_rate"],
           "BERT+WaveNet": df_wavenet.loc[ df_wavenet.epoch == wavenet_epoch, "WER_rate"],
           "Mel-Spec.+Wavenet": df_tc2_wavenet.loc[ df_tc2_wavenet.epoch == tc2_wavenet_epoch, "WER_rate"]}


possible_combinations = list(iter(combinations(["Tacotron2", "Baseline", "BERT+WaveNet", "Mel-Spec.+Wavenet"], 2)))
triplets = []

for i, pair in enumerate(possible_combinations):
    #print(pair)
    for model_a, model_b in [pair]:
        wer_a, wer_b = mapping[model_a].reset_index(drop=True), mapping[model_b].reset_index(drop=True)
        diff = wer_a - wer_b
        print(f"{model_a} vs. {model_b} & ", end='')
        data = [ diff.sample(2703, replace=True).mean() for _ in range(1000) ]
        triplet = np.quantile(data, sign_level/2), np.mean(data), np.quantile(data, 1 - sign_level/2)
        triplets.append(triplet)
        for t in triplet:
            print(f"{t:.3f}\t&", end='')
        print()
# Out:
# Tacotron2 vs. Baseline & -0.032	&-0.024	&-0.017	&
# Tacotron2 vs. BERT+WaveNet & -0.114	&-0.103	&-0.092	&
# Tacotron2 vs. Mel-Spec.+Wavenet & -0.145	&-0.131	&-0.119	&
# Baseline vs. BERT+WaveNet & -0.088	&-0.079	&-0.069	&
# Baseline vs. Mel-Spec.+Wavenet & -0.121	&-0.107	&-0.096	&
# BERT+WaveNet vs. Mel-Spec.+Wavenet & -0.036	&-0.028	&-0.019	&

# %%
# Set random seed 
random.seed(1)
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)

# Significance level
numb_comparisons = 6
sign_level = 0.05/numb_comparisons 

# Calculate statistics 
mapping = {"Tacotron2": df_tc2.loc[ df_tc2.epoch == tc2_epoch, "CER_rate"],
           "Baseline": df_base.loc[ df_base.epoch == base_epoch, "CER_rate"],
           "BERT+WaveNet": df_wavenet.loc[ df_wavenet.epoch == wavenet_epoch, "CER_rate"],
           "Mel-Spec.+Wavenet": df_tc2_wavenet.loc[ df_tc2_wavenet.epoch == tc2_wavenet_epoch, "CER_rate"]}


possible_combinations = list(iter(combinations(["Tacotron2", "Baseline", "BERT+WaveNet", "Mel-Spec.+Wavenet"], 2)))
triplets = []

for i, pair in enumerate(possible_combinations):
    #print(pair)
    for model_a, model_b in [pair]:
        wer_a, wer_b = mapping[model_a].reset_index(drop=True), mapping[model_b].reset_index(drop=True)
        diff = wer_a - wer_b
        print(f"{model_a} vs. {model_b} & ", end='')
        data = [ diff.sample(2703, replace=True).mean() for _ in range(1000) ]
        triplet = np.quantile(data, sign_level/2), np.mean(data), np.quantile(data, 1 - sign_level/2)
        triplets.append(triplet)
        for t in triplet:
            print(f"{t:.3f}\t&", end='')
        print()
# Out:
# Tacotron2 vs. Baseline & 0.136	&0.140	&0.144	&
# Tacotron2 vs. BERT+WaveNet & -0.051	&-0.047	&-0.044	&
# Tacotron2 vs. Mel-Spec.+Wavenet & -0.045	&-0.042	&-0.038	&
# Baseline vs. BERT+WaveNet & -0.191	&-0.187	&-0.184	&
# Baseline vs. Mel-Spec.+Wavenet & -0.185	&-0.181	&-0.177	&
# BERT+WaveNet vs. Mel-Spec.+Wavenet & 0.004	&0.006	&0.008	&

# %% [markdown]
# # One-sample non-parametric bootstrapping:

# %% [markdown]
# Helper function:

# %%
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)

def extract_file_extension(file_name:str):
    """
    >>> extract_file_extensions("some_path/works_with_backslashes\\and_2x_extensions.tar.gz")
    '.tar.gz'
    """
    assert file_name.find(".") != -1, "No ´.´ found"
    suffixes = pathlib.Path(file_name).suffixes
    return ''.join(pathlib.Path(file_name).suffixes)

def save_plt_plot(save_path, fig=None, dpi=300):
    assert extract_file_extension(save_path) in [".png", ".jpg", ".pdf"]
    if fig is None:
        plt.savefig(save_path, dpi = dpi, bbox_inches = 'tight')
    else:
        fig.savefig(save_path, dpi = dpi, bbox_inches = 'tight')

class _ColorHEX:
    def __init__(self):
        self.blue = "#1f77b4"
        self.orange = "#ff7f0e"
        self.green = "#2ca02c"
        self.red = "#d62728"
        self.purple = "#9467bd" 
        self.brown = "#8c564b"
        self.pink = "#e377c2"
        self.grey =  "#7f7f7f"
colors_hex = _ColorHEX()

# %% [markdown]
# WER one-sample non-parametric bootstrapping confidence intervals for all epochs:

# %%
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)

# Bootstrap
df_WER =  pd.DataFrame( np.ones((147*4, 4)), columns=["model_type", "mean", "low", "high"])
i = 0

for epoch in tqdm(range(1, 147)):
    mapping = {"Tacotron2": df_tc2.loc[ df_tc2.epoch == epoch, "WER_rate"],
               "Baseline": df_base.loc[ df_base.epoch == epoch, "WER_rate"],
               "BERT+WaveNet": df_wavenet.loc[ df_wavenet.epoch == epoch, "WER_rate"],
               "Mel-Spec.+Wavenet": df_tc2_wavenet.loc[ df_tc2_wavenet.epoch == epoch, "WER_rate"]}

    
    for model in list(mapping.keys()):
        wer = mapping[model]
        data = [ wer.sample(2703, replace=True).mean() for _ in range(1000) ]
        df_WER.iloc[i] = model, np.mean(data), np.quantile(data, 0.025), np.quantile(data, 0.975)
        i += 1
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=146.0), HTML(value='')))

# %%
df_tc2_epoch
# Out:
# epoch
# 1      308.250259
# 2      306.675129
# 3      305.698504
# 4      302.422060
# 5      297.256975
#           ...
# 175    685.081557
# 176    685.829501
# 177    685.753052
# 178    685.732314
# 179    681.529506
# Name: CTC_loss, Length: 179, dtype: float64

# %%
# Plots
fig, ax = plt.subplots(dpi=180,figsize=(10, 4))

mapping = {"Tacotron2":(df_tc2_epoch,colors_hex.blue),
           "Baseline":(df_wavenet_epoch,colors_hex.orange),
           "BERT+WaveNet":(df_base_epoch,colors_hex.green),
           "Mel-Spec.+Wavenet":(df_tc2_wavenet_epoch, colors_hex.red)}

for model in mapping.keys():
    data, color = mapping[model]
    ax.plot(data[:147], color=color, label=f'{model}')
    ax.legend()
    
ax.set_xlabel("Epochs")
ax.set_ylabel("CTC Loss (sum over batch)")

plt.tight_layout()

plt.savefig("./CTC_loss.pdf", dpi = 180, bbox_inches = 'tight')

# %% [markdown]
# CER one-sample non-parametric bootstrapping confidence intervals for all epochs:

# %%
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)

# Bootstrap
df_CER =  pd.DataFrame( np.ones((147*4, 4)), columns=["model_type", "mean", "low", "high"])
i = 0

for epoch in tqdm(range(1, 147)):
    mapping = {"Tacotron2": df_tc2.loc[ df_tc2.epoch == epoch, "CER_rate"],
               "Baseline": df_base.loc[ df_base.epoch == epoch, "CER_rate"],
               "BERT+WaveNet": df_wavenet.loc[ df_wavenet.epoch == epoch, "CER_rate"],
               "Mel-Spec.+Wavenet": df_tc2_wavenet.loc[ df_tc2_wavenet.epoch == epoch, "CER_rate"]}
    
    for model in list(mapping.keys()):
        wer = mapping[model]
        data = [ wer.sample(2703, replace=True).mean() for _ in range(1000) ]
        df_CER.iloc[i] = model, np.mean(data), np.quantile(data, 0.025), np.quantile(data, 0.975)
        i += 1
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=146.0), HTML(value='')))

# %%
fig, axs = plt.subplots(2,1,dpi=180,figsize=(10, 8))

mapping = {"Tacotron2":(df_tc2_epoch,colors_hex.blue), 
           "Baseline":(df_wavenet_epoch,colors_hex.orange), 
           "BERT+WaveNet":(df_base_epoch,colors_hex.green),
           "Mel-Spec.+Wavenet": (df_tc2_wavenet_epoch, colors_hex.red)}


for model in list(mapping.keys()):
    _ , color = mapping[model]
    data = df_WER[df_WER["model_type"] == model ].drop(columns=["model_type"]).to_numpy()

    xs = np.arange(len(data))

    mean, low, high = np.array(data)[:,0], np.array(data)[:,1], np.array(data)[:,2]

    axs[0].plot(mean, color=color, label=f'{model}')
    plt.sca(axs[0]) # <-- makes gca work, super wierd but gets the job done
    plt.gca().fill_between(xs, high, low,  color=color, alpha=0.5) #, label=f'{model} - 95% conf.'
    axs[0].legend()
    axs[0].set_title('Word Error Rate')
    
for model in list(mapping.keys()):
    _ , color = mapping[model]
    data = df_CER[df_CER["model_type"] == model ].drop(columns=["model_type"]).to_numpy()

    xs = np.arange(len(data))

    mean, low, high = np.array(data)[:,0], np.array(data)[:,1], np.array(data)[:,2]

    axs[1].plot(mean, color=color, label=f'{model}')
    plt.sca(axs[1]) # <-- makes gca work, super wierd but gets the job done
    plt.gca().fill_between(xs, high, low,  color=color, alpha=0.5) #, label=f'{model} - 95% conf.'
    axs[1].legend()
    axs[1].set_title('Character Error Rate')


plt.savefig("./bootstrap_results.pdf", dpi = 180, bbox_inches = 'tight')

# %% [markdown]
# # Paired two-sample t-test:

# %%
def one_sample_t_test1(data,rows):
    diffs = data[rows[0]].reset_index(drop=True) - data[rows[1]].reset_index(drop=True)            
    stats = st.ttest_1samp(diffs, 0)
    
    return stats[1], diffs.mean()
order = [[0,1],[0,2],[0,3],[1,2],[1,3],[2,3]]
ps1 = []
ts1 = []
ps2 = []
ts2 = []
for o in order:
    p1, t_obs1 = one_sample_t_test1(list1,o)
    ps1.append(p1)
    ts1.append(t_obs1)
    p2, t_obs2 = one_sample_t_test1(list2,o)
    ps2.append(p2)
    ts2.append(t_obs2)
# Test: WER
#p1 = one_sample_t_test1(list1,[0,1])[1]
#p2 = one_sample_t_test1(list1,[0,2])[1]
#p3 = one_sample_t_test1(list1,[0,3])[1]
#p4 = one_sample_t_test1(list1,[1,2])[1]
#p5 = one_sample_t_test1(list1,[1,3])[1]
#p6 = one_sample_t_test1(list1,[2,3])[1]

# Test: CER
#p7 = one_sample_t_test1(list2,[0,1])[1]
#p8 = one_sample_t_test1(list2,[0,2])[1]
#p9 = one_sample_t_test1(list2,[0,3])[1]
#p10 = one_sample_t_test1(list2,[1,2])[1]
#p11 = one_sample_t_test1(list2,[1,3])[1]
#p12 = one_sample_t_test1(list2,[2,3])[1]

# Bonferroni correct p-values 
numb_comparisons = 6
pvals1 = np.array(ps1) * numb_comparisons 
pvals2 = np.array(ps2) * numb_comparisons

# %%
for i in range(6):
    print(f"p-value {i}: {pvals1[i]:.3e}")
for i in range(6):
    print(f"p-value {i}: {pvals2[i]:.3e}")
# Out:
# p-value 0: 2.738e-117
# p-value 1: 1.499e-89
# p-value 2: 1.517e-189
# p-value 3: 9.125e-15
# p-value 4: 8.299e-16
# p-value 5: 5.107e-79
# p-value 0: 1.951e-280
# p-value 1: 0.000e+00
# p-value 2: 0.000e+00
# p-value 3: 0.000e+00
# p-value 4: 0.000e+00
# p-value 5: 2.868e-61

# %%
names = ["wavenet", "tc2", "base", "mel"]

p_labels = [f"{names[i]} vs. {names[j]}" for i,j in order]

# %%
def pretty_print_float(f):
    flt = "{0:.3e}".format(f)
    b, e = flt.split("e")
    e = "{"+str(int(e))+"}"
    return f"${b} \cdot 10^{e}$"

# %%
for i,l in enumerate(p_labels):
    print(f"{l}\t & {pretty_print_float(pvals1[i])}\t & {pretty_print_float(ts1[i])}\t  & {pretty_print_float(pvals2[i])}\t & {pretty_print_float(ts2[i])}\\\\")
# Out:
# wavenet vs. tc2	 & $2.738 \cdot 10^{-117}$	 & $1.028 \cdot 10^{-1}$	  & $1.951 \cdot 10^{-280}$	 & $4.736 \cdot 10^{-2}$\\
# wavenet vs. base	 & $1.499 \cdot 10^{-89}$	 & $7.887 \cdot 10^{-2}$	  & $0.000 \cdot 10^{0}$	 & $1.871 \cdot 10^{-1}$\\
# wavenet vs. mel	 & $1.517 \cdot 10^{-189}$	 & $1.258 \cdot 10^{-1}$	  & $0.000 \cdot 10^{0}$	 & $2.079 \cdot 10^{-1}$\\
# tc2 vs. base	 & $9.125 \cdot 10^{-15}$	 & $-2.395 \cdot 10^{-2}$	  & $0.000 \cdot 10^{0}$	 & $1.398 \cdot 10^{-1}$\\
# tc2 vs. mel	 & $8.299 \cdot 10^{-16}$	 & $2.300 \cdot 10^{-2}$	  & $0.000 \cdot 10^{0}$	 & $1.606 \cdot 10^{-1}$\\
# base vs. mel	 & $5.107 \cdot 10^{-79}$	 & $4.695 \cdot 10^{-2}$	  & $2.868 \cdot 10^{-61}$	 & $2.079 \cdot 10^{-2}$\\

# %% [markdown]
# # One-sample t-test:

# %%
# Save data
def do_t_test(col='WER_rate'):
    WaveNet_conf = np.zeros((147,3))
    tc2_conf = np.zeros((147,3))
    base_conf = np.zeros((147,3))
    tc2_wavenet_conf = np.zeros((147,3))

    for i in range(1,147):
        # Calculate parameters
        X_wavenet = df_wavenet[col][df_wavenet['epoch'] == i]
        mean1 = np.mean(X_wavenet)
        scale1 = st.sem(X_wavenet)
        
        X_tc2 = df_tc2[col][df_tc2['epoch'] == i]
        mean2 = np.mean(X_tc2)
        scale2 = st.sem(X_tc2)
        
        X_base = df_base[col][df_base['epoch'] == i]
        mean3 = np.mean(X_base)
        scale3 = st.sem(X_base)
        
        X_tc2_wavenet = df_tc2_wavenet[col][df_tc2_wavenet['epoch'] == i]
        mean4 = np.mean(X_tc2_wavenet)
        scale4 = st.sem(X_tc2_wavenet)

        # Make t-tests 
        low1, up1 = st.t.interval(alpha=0.95, df=2703-1, loc=mean1, scale=scale1)
        low2, up2 = st.t.interval(alpha=0.95, df=2703-1, loc=mean2, scale=scale2)
        low3, up3 = st.t.interval(alpha=0.95, df=2703-1, loc=mean3, scale=scale3)
        low4, up4 = st.t.interval(alpha=0.95, df=2703-1, loc=mean4, scale=scale4)
        
        # Save data
        WaveNet_conf[i,:] = [mean1,low1,up1]
        tc2_conf[i,:] = [mean2,low2,up2]
        base_conf[i,:] = [mean3,low3,up3]
        tc2_wavenet_conf[i,:] = [mean4,low4,up4]
    return WaveNet_conf, tc2_conf, base_conf, tc2_wavenet_conf

# %%
WaveNet_conf_WER, tc2_conf_WER, base_conf_WER, tc2_wavenet_conf_WER = do_t_test(col='WER_rate')
WaveNet_conf_CER, tc2_conf_CER, base_conf_CER, tc2_wavenet_conf_CER = do_t_test(col='CER_rate')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2099: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#plot

fig, axs = plt.subplots(2,1,dpi=180,figsize=(10, 8))

mapping1 = {"Tacotron2":(tc2_conf_WER,colors_hex.blue), 
           "Baseline":(base_conf_WER,colors_hex.orange), 
           "BERT+WaveNet":(WaveNet_conf_WER,colors_hex.green),
           "Mel-Spec.+Wavenet": (tc2_wavenet_conf_WER, colors_hex.red)}

mapping2 = {"Tacotron2":(tc2_conf_CER,colors_hex.blue), 
           "Baseline":(base_conf_CER,colors_hex.orange), 
           "BERT+WaveNet":(WaveNet_conf_CER,colors_hex.green),
           "Mel-Spec.+Wavenet": (tc2_wavenet_conf_CER, colors_hex.red)}

for ax, lab, mapping in zip(axs, ["Word Error Rate", "Character Error Rate"], [mapping1,mapping2]):
    for model in list(mapping.keys()):
        data , color = mapping[model]
        cutoff = 5
        xs = np.array(range(cutoff,len(data)))

        mean, low, high = data[cutoff:,0], data[cutoff:,1], data[cutoff:,2]

        ax.plot(xs,mean, color=color, label=f'{model}')
        plt.sca(ax) # <-- makes gca work, super wierd but gets the job done
        plt.gca().fill_between(xs, high, low,  color=color, alpha=0.5) #, label=f'{model} - 95% conf.'
        ax.legend()
    
    ax.set_xlabel("Epochs")
    ax.set_ylabel(lab)

plt.tight_layout()

plt.savefig("./t-test-statistic.pdf", dpi = 180, bbox_inches = 'tight')
