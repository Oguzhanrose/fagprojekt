# %%
with open('dev-clean.txt', 'a+') as f1:
    for trans in glob('/work3/s194278/fagprojekt/LibriSpeech/dev-clean/*/*/*.trans.txt'):
        with open(trans, 'r') as f2:
            for l in f2.readlines():
                print(l.rstrip(), file=f1)

# %%
with open('dev-clean.txt', 'r') as f:
    lines = f.readlines()

# %%
l = lines[0]

# %%
def split_line(line):
    idx = line.split(" ")[0]
    trans = line[len(idx)+1:].rstrip()
    return idx, trans
trans_dict = dict([split_line(l) for l in lines])

# %%
trans_dict
# Out:
# {'3853-163249-0000': 'HER MEETING WITH LETTY WAS INDESCRIBABLY TENDER AND THE DAYS THAT FOLLOWED WERE PRETTY EQUALLY DIVIDED BETWEEN HER AND HER BROTHER IN NURSING THE ONE AND LOVING THE OTHER',
#  '3853-163249-0001': 'BUT EVEN WHILE SHE ENJOYED EVERY HOUR OF LIFE AND BEGRUDGED THE TIME GIVEN TO SLEEP SHE FELT AS IF THE DREAM WAS TOO BEAUTIFUL TO LAST AND OFTEN SAID',
#  '3853-163249-0002': 'SO CHRISTIE TURNED A DEAF EAR TO HER PROPHETIC SOUL AND GAVE HERSELF UP TO THE BLISSFUL HOLIDAY THAT HAD COME AT LAST',
#  '3853-163249-0003': "NOTHING CAN SURPRISE ME NOW I'M PREPARED FOR ANY THING EVEN THE SIGHT OF MY QUAKERISH LOVER DANCING A JIG",
#  '3853-163249-0004': 'I FEEL LIKE A BOY OUT OF SCHOOL OR RATHER A MAN OUT OF PRISON AND MUST ENJOY MY LIBERTY IN SOME WAY',
#  '3853-163249-0005': "I'M NOT A TALKER YOU KNOW AND AS THE LAWS OF GRAVITATION FORBID MY SOARING ALOFT ANYWHERE I CAN ONLY EXPRESS MY JOYFULLY UPLIFTED STATE OF MIND BY PRANCING AS YOU CALL IT",
# ...

# %%
os.path.splitext('hej.flac')[0]
# Out:
# 'hej'
